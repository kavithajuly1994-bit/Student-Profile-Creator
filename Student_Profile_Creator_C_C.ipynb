# %%
Project Title: Student Profile Creator
Scenario:
 You are helping to build a basic student information system for a local school. The school wants to store some basic details about each student and let them update their interests.
Tasks:
Create variables to store the student’s name, age, and their favourite subjects they are enrolled in.
Display the student’s information in a user-friendly format.
Display the updated list of subjects.
for getting input use this method===> variable_name=input("Enter the name"/any prompt)



name = input("Enter your name: ")
age = input("Enter your age: ")
subjects = input("Enter your favourite subjects: ")

print("\n--------STUDENT'S PROFILE--------\n")
print("Name:", name)
print("Age:", age)
print("Favourite subjects:", subjects)

new_subject = input("\nEnter additional subject to add: ")

subjects = subjects + ", " + new_subject

print("\nUpdated subjects:", subjects)
# Out:
# Enter your name: kavitha
# Enter your age: 32
# Enter your favourite subjects: Excel, SQL, Power BI
#
# --------STUDENT'S PROFILE--------
#
# Name: kavitha
# Age: 32
# Favourite subjects: Excel, SQL, Power BI
#
# Enter additional subject to add: Python
#
# Updated subjects: Excel, SQL, Power BI, Python
